# %%
# 파이썬의 조건문은 
# 조건문 안의 영역을 들여쓰기로 구분

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 조건문 if
if 2>1:
    print('해당 조건식은 트루입니다~')
    
if 2<1: # False 조건문 안을 확인 x 셀 실행 멈춤
    print('조건문 안이에요 ~ ')
# Out:
# 해당 조건식은 트루입니다~

# %%
# 들여쓰기의 중요성
if True:
    print('조건문 안 실행문장')
print('조건문 밖 실행문장')
# Out:
# 조건문 안 실행문장
# 조건문 밖 실행문장

# %%
if False:
    print('조건문 안 실행문장')
print('조건문 밖 실행문장')
# Out:
# 조건문 밖 실행문장

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
money = 9000
if money >= 10000:
    print('택시를 탄다')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# if - else
if True:
    print('실행문장1')
else:
    print('실행문장2')
# Out:
# 실행문장1

# %%
if False:
    print('실행문장1')
else:
    print('실행문장2')
# Out:
# 실행문장2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
money = 9000
if money>=10000:
    print('택시를 탄다!!!')
else:
    # 10000원 미만일 때 
    print('버스를 탄다 !!!')
# Out:
# 버스를 탄다 !!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = int(input('정수 입력 >> '))
# 3배수 : 3으로 나눴을 때 나머지가 0
# 5배수 : 5으로 나눴을 때 나머지가 0
if num%3==0 and num%5==0:
    print('3과 5의 배수입니다.')
else:
    print('3과 5의 배수가 아닙니다.')
# Out:
# 정수 입력 >> 15
# 3과 5의 배수입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1 = int(input('첫번째 정수 입력>> '))
num2 = int(input('두번째 정수 입력>> '))
if num1 > num2:
    print('첫 번째 정수가 더 큽니다.')
elif num1 < num2:
    print('두 번째 정수가 더 큽니다.')
else:
    print('두 수가 똑같습니다.')
# Out:
# 첫번째 정수 입력>> 5
# 두번째 정수 입력>> 5
# 두 수가 똑같습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def print_menu():
    print("""
================================================
================---- 자판기 ----================
================================================
== 1.콜라 == 2.사이다 ==  3.물  =======insert===
==--------==----------==--------=======------===
==   600  ==    800   ==  1000  ======= O00원===
=======================================------===
================================================
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==+++++++++++++++              +++++++++++++++==
==+++++++++++++++     SMHRD    +++++++++++++++==
==+++++++++++++++              +++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
================================================
================================================
  ===                                      ===
  ===                                      ===""")

# %%
print_menu()
# 메뉴, 금액 출력
# 돈 입력
# 메뉴 선택 입력
# 조건식 판별
# 입력받은 돈에서 입력받은 메뉴 금액만큼 빼기 
# 조건식 판별
# - 금액 부족 출력
# - 거스름돈 걸러서 출력 
input_coin = int(input('금액 넣기>> '))
choice_mn = int(input('메뉴 선택(번호입력)>> '))
ch,ob,b,change_money = 0,0,0,0

if choice_mn == 1:
    change_money = input_coin - 600 # 콜라
elif choice_mn ==2:
    change_money = input_coin - 800 # 사이다
else :
    change_money = input_coin - 1000 # 물

#잔돈 변환
if change_money<0:
    print('금액이 부족합니다.')
else:
    ch = change_money//1000
    ob = change_money%1000//500
    b  = change_money%1000%500//100  
    print(f'거스름돈 >> 1000원 {ch}개 500원 {ob}개 100원 {b}개')
# Out:
# ================================================
# ================---- 자판기 ----================
# ================================================
# == 1.콜라 == 2.사이다 ==  3.물  =======insert===
# ==--------==----------==--------=======------===
# ==   600  ==    800   ==  1000  ======= O00원===
# =======================================------===
# ================================================
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==+++++++++++++++              +++++++++++++++==
# ==+++++++++++++++     SMHRD    +++++++++++++++==
# ==+++++++++++++++              +++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ================================================
# ================================================
#   ===                                      ===
#   ===                                      ===
